# %% [markdown]
# <a href="https://colab.research.google.com/github/khanittha-phusopha/multivariate-/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multidimensional Scaling
#
# # 1.   รายการในลิสต์
# ![download (3).png](data:image/png;base64,...)

# %% [markdown]
# ##MDS (มาตราส่วนหลายมิติ)
# คืออัลกอริทึมที่เปลี่ยนชุดข้อมูลอื่นโดยปกติจะมีขนาดที่ต่ำกว่าโดยรักษาระยะห่างแบบยุคลิดที่เท่าๆกัน

# %% [markdown]
# # **Example on iris dataset**

# %%
import pandas as pd

# %%
example_df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
example_df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.decomposition import  PCA

# %%
pca = PCA(n_components=2)

# %%
new_pca = pca.fit_transform(example_df.iloc[:,:-1])

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(new_pca[:50,0],new_pca[:50,1], '*g' , label='Setosa')
plt.plot(new_pca[50:100,0],new_pca[50:100,1], '+b' , label='Versicolor')
plt.plot(new_pca[100:,0],new_pca[100:,1], 'ok' , label='Virginica')
plt.legend()

# %% [markdown]
# ## MDS (Multidimensional Scaling)##
# ![download (4).png](data:image/png;base64,...)

# %% [markdown]
# # Distance

# %%
X1 = example_df.iloc[0,:-1].to_numpy()
X1          #เอาทุกdimantionยกเว้นชื่อ
# Out:
# array([5.1, 3.5, 1.4, 0.2], dtype=object)

# %%
X2 = example_df.iloc[1,:-1].to_numpy()
X2
# Out:
# array([4.9, 3.0, 1.4, 0.2], dtype=object)

# %%
import numpy as np

# %%
dist = np.linalg.norm(X1-X2)
dist           #คำนวณระยะห่างระหว่างจุด X1กับX2  โดยใช้สูตรในโปรแกรม
# Out:
# 0.5385164807134502

# %%
(0.04 + 0.25)**(0.05)
#คำนวณโดยนำตัวเลขมาคิดไม่ได้ใช้สูตร
# Out:
# 0.9399827849205659

# %% [markdown]
# ##Distance Matrix##
# ![download (5).png](data:image/png;base64,...)

# %%
from sklearn.metrics import pairwise_distances
dis_matrix = pairwise_distances(example_df.iloc[:,:-1])
dis_matrix
# Out:
# array([[0.        , 0.53851648, 0.50990195, ..., 4.45982062, 4.65080638,
#         4.14004831],
#        [0.53851648, 0.        , 0.3       , ..., 4.49888875, 4.71805044,
#         4.15331193],
#        [0.50990195, 0.3       , 0.        , ..., 4.66154481, 4.84871117,
#         4.29883705],
#        ...,
#        [4.45982062, 4.49888875, 4.66154481, ..., 0.        , 0.6164414 ,
#         0.64031242],
#        [4.65080638, 4.71805044, 4.84871117, ..., 0.6164414 , 0.        ,
#         0.76811457],
#        [4.14004831, 4.15331193, 4.29883705, ..., 0.64031242, 0.76811457,
#         0.        ]])

# %%
plt.imshow(dis_matrix)
#จะเห็นได้ว่ากราฟที่มีค่ามาก(ห่างมาก) ยิ่งมีสีที่สว่าง ถ้าค่าน้อย(ชิดกัน) ยิ่งมีสีที่เข้มขึ้นจากเดิม

# %% [markdown]
# ## ทำ MDS

# %%
from sklearn.manifold import  MDS

# %%
mds = MDS(n_components=2)

# %%
new_mds = mds.fit_transform(example_df.iloc[:,:-1])

# %%
new_mds
# Out:
# array([[-2.3105629 ,  1.42271305],
#        [-2.56327302,  0.94765002],
#        [-2.69312799,  1.09143009],
#        [-2.64240843,  0.84266038],
#        [-2.34258084,  1.46863752],
#        [-1.74295176,  1.66353315],
#        [-2.6226087 ,  1.1383161 ],
#        [-2.32150151,  1.25542035],
#        [-2.87161539,  0.68327547],
#        [-2.48953003,  1.0023884 ],
#        [-1.99637945,  1.65831939],
#        [-2.36856367,  1.12031473],
#        [-2.6497452 ,  0.92825729],
#        [-3.15063362,  0.89249374],
#        [-1.88845136,  2.22411911],
#        [-1.57964079,  2.26125854],
#        [-2.0294706 ,  1.87811339],
#        [-2.27651686,  1.41055031],
#        [-1.61405833,  1.73984512],
#        [-2.12774435,  1.59602673],
#        [-1.92254324,  1.33412494],
#        [-2.1182436 ,  1.50063151],
#        [-2.88040042,  1.51384333],
#        [-2.04331825,  1.06655001],
#        [-2.17074616,  0.90724012],
#        [-2.36118862,  0.87082711],
#        [-2.18320851,  1.16879925],
# ...

# %%
plt.plot(new_mds[:50,0],new_mds[:50,1], '*b' , label='Setosa')
plt.plot(new_mds[50:100,0],new_mds[50:100,1], '*r' , label='Versicolor')
plt.plot(new_mds[100:,0],new_mds[100:,1], '*y' , label='Virginica')
plt.legend()
#plot graph ดูข้อมูบระยะห่างแต่ละจุด โดยที่กราฟแต่ละคนจะไม่เหมือนกัน

# %%
plt.plot(new_mds[:50,0],new_mds[:50,1], '*b' , label='Setosa')
plt.plot(new_mds[50:100,0],new_mds[50:100,1], '*r' , label='Versicolor')
plt.plot(new_mds[100:,0],new_mds[100:,1], '*y' , label='Virginica')
plt.plot(new_mds[6,0],new_mds[6,1], 'og') 
plt.plot(new_mds[56,0],new_mds[56,1], 'ok')
plt.plot(new_mds[116,0],new_mds[116,1], 'om')
plt.legend()
#plot grapg ดูจุดในแต่ละข้อมูลว่าอยู่ในแนวเดียวกันหรือไม่
#og แทนข้อมูลตัวที่6 เป็นวงกลมสีเขียว
#ok แทนข้อมูลตัวที่56 เป็นวงกลมสีดำ
#om แทนข้อมูลตัวที่116 เป็นวงกลมสีม่วง

# %% [markdown]
# ### การใช้ Pre-computed Distance Matrix

# %%
mds2 = MDS(n_components=2, dissimilarity='precomputed')

# %%
new_mds2 = mds2.fit_transform(dis_matrix)

# %%
plt.plot(new_mds2[:50,0],new_mds2[:50,1], '*k' , label='Setosa')
plt.plot(new_mds2[50:100,0],new_mds2[50:100,1], '*m' , label='Versicolor')
plt.plot(new_mds2[100:,0],new_mds2[100:,1], '*g' , label='Virginica')
plt.plot(new_mds[6,0],new_mds2[6,1], 'ob')
plt.plot(new_mds2[56,0],new_mds2[56,1], 'or')
plt.plot(new_mds2[116,0],new_mds2[116,1], 'oy')
plt.legend()

# %% [markdown]
# # Example 2
#
# https://jakevdp.github.io/PythonDataScienceHandbook/05.10-manifold-learning.html?fbclid=IwAR1PP7bL5QkJyYM87IG3GE4gLdKAYkz8TXDp1sgIhVDWPi8JrjCT4wkHJVs

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
#seaborn นำเข้าข้อมูลสำหรับplot graph ให้ดูสวย

# %%
def make_hello(N=1000, rseed=42):     #N คือ จำนวนที่plot graph จะplotทั้งหมด 1000จุด
    # Make a plot with "HELLO" text; save as PNG
    fig, ax = plt.subplots(figsize=(4, 1))
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1)
    ax.axis('off')
    ax.text(0.5, 0.4, 'HELLO', va='center', ha='center', weight='bold', size=85)
    fig.savefig('hello.png')
    plt.close(fig)
    
    # Open this PNG and draw random points from it
    from matplotlib.image import imread
    data = imread('hello.png')[::-1, :, 0].T
    rng = np.random.RandomState(rseed)
    X = rng.rand(4 * N, 2)
    i, j = (X * data.shape).astype(int).T
    mask = (data[i, j] < 1)
    X = X[mask]
    X[:, 0] *= (data.shape[0] / data.shape[1])
    X = X[:N]
    return X[np.argsort(X[:, 0])]

# %%
X = make_hello(1000)
colorize = dict(c=X[:, 0], cmap=plt.cm.get_cmap('rainbow', 5))
plt.scatter(X[:, 0], X[:, 1], **colorize)
plt.axis('equal');   #plot graph โดยใส่สี

# %%
X = make_hello(1000)

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.scatter(X[:,0],X[:,1])
plt.axis('equal');  #plot graph โดยไม่ใส่สี
#plt.axis('equal'); เป็นการทำให้scale

# %%
colorize = dict(c=X[:, 0], cmap=plt.cm.get_cmap('rainbow', 5))

# %%
colorize['c'].shape
# Out:
# (1000,)

# %%
colorize['cmap']

# %%
plt.scatter(X[:, 0], X[:, 1], **colorize)
plt.axis('equal');

# %%
def rotate(X, angle):
    theta = np.deg2rad(angle)
    R = [[np.cos(theta), np.sin(theta)],
         [-np.sin(theta), np.cos(theta)]]
    return np.dot(X, R)

# %%
X2 = rotate(X, 20) 
plt.scatter(X2[:, 0], X2[:, 1], **colorize)
plt.axis('equal');\
#หมุนไปแกน x 20 องศา

# %%
X2 = rotate(X, 45) 
plt.scatter(X2[:, 0], X2[:, 1], **colorize)
plt.axis('equal');\
#หมุนไปแกน x 45 องศา

# %%
X2 = rotate(X, 20) + 5
plt.scatter(X2[:, 0], X2[:, 1], **colorize)
plt.axis('equal');
#หมุนไปแกน x 20 องศา และเริ่มต้นจากจุดที่ 5

# %% [markdown]
# ##MDS##

# %%
from sklearn.metrics import pairwise_distances
D = pairwise_distances(X)
D.shape
# Out:
# (1000, 1000)

# %%
plt.imshow(D, zorder=2, cmap='Blues', interpolation='nearest')
plt.colorbar();  ##บอก scale bar ว่าหมายถึงอะไร
#ถ้าระยะห่างกันมากสีก็ยิ่งจะเข้มมาก

# %%
D2 = pairwise_distances(X2)
#ระยะห่างของตัวหมุน

# %%
from sklearn.manifold import MDS
model = MDS(n_components=2, dissimilarity='precomputed', random_state=1)
out = model.fit_transform(D)
plt.scatter(out[:, 0], out[:, 1], **colorize)
plt.axis('equal');
#random state ดูว่ากราฟจะไม่เหมือนกันเวลาหมุน อยู่คนละทิศแต่ระยะห่างเท่าเดิม

# %%
model = MDS(n_components=2, dissimilarity='precomputed')
out = model.fit_transform(D)
plt.scatter(out[:, 0], out[:, 1], **colorize)
plt.axis('equal');
#ไม่มีrandom state

# %% [markdown]
# # Quiz 4
#
# #    ทดสองทำ pca กับข้อมูล ```X``` แล้ว plotgraph
# #    และดูผลว่าการกระจายของข้อูลมันเปลี่ยนแปลงไปหรือไม่ อย่างไร
#
# ส่งก่อน 14.15  commit ว่า quiz 4

# %%
from sklearn.decomposition import  PCA

# %%
pca = PCA(n_components=2)

# %%
X_pca = pca.fit_transform(X)

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(X_pca[:,0],X_pca[:,1])
plt.axis()
# Out:
# (-2.1335389649602305,
#  2.2618710063883154,
#  -0.47029603964119726,
#  0.5153973483729077)

# %% [markdown]
# # เฉลย

# %%
model = MDS(n_components=2, dissimilarity='precomputed')
out = model.fit_transform(D2)
plt.scatter(out[:, 0], out[:, 1], **colorize)
plt.axis('equal');

# %%
model = PCA(n_components=2)
out = model.fit_transform(X2)
plt.scatter(out[:, 0], out[:, 1], **colorize)
plt.axis('equal');

# %%
model = PCA(n_components=2)
out = model.fit_transform(X2)
plt.scatter(out[:, 0], out[:, 1], **colorize)
plt.axis('equal');

# %% [markdown]
# PCA หา eigenvalue
# * zorder
# *
